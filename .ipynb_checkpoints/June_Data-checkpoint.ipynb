# %%
import pandas as pd

# %%
april_data = pd.read_excel("D:/Office Work/NB_Walkin_Analysis/04-07-2019/Affiliates/Affiliates_June_Final_Overlap_v1.xlsx")
april_data = april_data.reset_index()
april_data = april_data.drop_duplicates(subset=['Phone_No_Model_ID','Channel']).reset_index(drop=True)
april_data.head()
# Out:
#    index  LEAD_ID  Phone_No_Model_ID TO_DATE(CREATED_AT)     Channel  \
# 0      0  8090102         7000747570          2019-05-15  Affiliates
# 1      1  8091062         9323111722          2019-05-15  Affiliates
# 2      2  8092991         8368190886          2019-05-15  Affiliates
# 3      3  8092604         8376037346          2019-05-15  Affiliates
# 4      4  8099288         8397729723          2019-05-16  Affiliates
#
#           Inspected_Flag
# 0  These are Evaluations
# 1  These are Evaluations
# 2  These are Evaluations
# 3  These are Evaluations
# 4  These are Evaluations

# %%
april_data_pivot = pd.crosstab(april_data.Phone_No_Model_ID,april_data.Channel)
april_data_pivot = april_data_pivot.reset_index()
april_data_pivot_slice = april_data_pivot.loc[(april_data_pivot['Affiliates'] >= 1) & (april_data_pivot['WALKIN'] >= 1)]

# %%
april_data_pivot_slice
# Out:
# Channel  Phone_No_Model_ID  Affiliates  WALKIN
# 58              6280048900           1       1
# 261             6381369698           1       1
# 1316            7082604454           1       1
# 1627            7299026868           1       1
# 2075            7415180886           1       1
# 2398            7583810008           1       1
# 2896            7755922010           1       1
# 3487            7891713442           1       1
# 3572            7899418041           1       1
# 3831            7982096867           1       1
# 3938            7986567127           1       1
# 4150            8005897700           1       1
# 4918            8115000090           1       1
# 6101            8337082911           1       1
# 6208            8368403406           1       1
# 6361            8384027530           1       1
# 6816            8471035189           1       1
# 7234            8588808468           1       1
# 7291            8600003460           1       1
# ...

# %%
april_data_pivot_slice.to_excel("D:/Office Work/NB_Walkin_Analysis/04-07-2019/Affiliates/Affilates_April_Final_Overlap_v2.xlsx", index=False)

# %%
april_data_pivot.head()
# Out:
# Channel  Phone_No_Model_ID  Affiliates  WALKIN
# 0               6000257383           1       0
# 1               6001490841           1       0
# 2               6003000085           0       1
# 3               6005189812           1       0
# 4               6005267565           1       0

# %%
april_data_pivot_slice.head()
# Out:
# Channel  Phone_No_Model_ID  Affiliates  WALKIN
# 541             7007985788           1       1
# 949             7020597792           1       1
# 1202            7042878433           1       1
# 1217            7043888536           1       1
# 1727            7276023456           1       1
